# %%
import theano
from theano import tensor as T
import neuralcraft

# %%
# %load_ext autoreload
# %autoreload 2

# %%
neuralcraft.test.LSTMTest()
# Out:
# 0.850857436657
# [array([[ 0.9106921 , -1.06166208],
#        [-0.14062999, -0.50399631],
#        [-0.13650151, -0.50116038],
#        [-0.00818043, -0.5239889 ]], dtype=float32), array([-0.00245882,  0.01211787], dtype=float32), array([[-0.89320958,  1.01884127, -0.56025273,  1.19630682],
#        [ 0.58353692,  0.50561523,  1.27006817, -1.48276269],
#        [ 1.01914108,  0.65777993, -2.08702803,  0.16590253]], dtype=float32), array([ 0.5108555 , -0.62025547, -0.49616751, -0.21166605], dtype=float32), array([[-1.58135188, -0.1728746 ,  0.29713398, -0.12688825],
#        [ 2.10243988,  0.01135938, -0.24954298,  0.41815662],
#        [ 0.84461087, -1.34934223,  0.22812301, -0.05237139],
#        [ 0.59866238, -0.98871005,  0.75158507,  0.18751532]], dtype=float32), array([[ 0.36269173,  0.17871076, -1.1136173 ,  0.88517636],
#        [-1.19193625,  2.28839779, -0.60312921, -0.92026818],
# ...
